# %% [markdown]
# ###### PROJECT CODE ######

# %% [markdown]
# # Analysis of CSFD and IMDB movie ratings

# %% [markdown]
# ### Kateřina Havelková, Jolana Čermáková

# %% [markdown]
# We have decided to focus on a movie analysis as we both watch movies often and therefore we were interested in the fact how the most famous movie databases work from inside out. We were following the procedure of web scraping and implementing it on both the CSDF and IMDB databases.
# We considered reasonable number of top movies from both websites and looked for the differences between them.

# %% [markdown]
# The biggest obstacle was to compare the number of votes quantitatively as on CSFD there is no particular number of votes given. There is just number of fans instead, which does not correspond to the total number of reviews. Because of that, we were forced to rely particularly on movie ratings - on IMDB, the movie rating is stated in two measures - basic 10-scale rating and also metascore obtained from professional movie critics. On CSFD, the movie rating is stated in one measure in percent.

# %% [markdown]
# #### First obtaining top rated films from CSFD page

# %%
#300 top rated movies by CSFD

# %%
from requests import get
url = 'https://www.csfd.cz/zebricky/nejoblibenejsi-filmy/?show=complete'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="cs" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://developers.facebook.com/schema/">
# <head>
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# 	<meta name="description" content="ČSFD.cz">
# 	<meta name="theme-color" content="#bb0011">
#
#
# 	<title>Žebříčky | ČSFD.cz</title>
#
# 	<link rel="shortcut icon" href="htt

# %%
from bs4 import BeautifulSoup

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
#aggregating data: name of the film and release year

# %%
movie_containers = html_soup.find_all('td', class_ = 'film')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 300

# %%
##aggregating data: csfd rating

# %%
movie_ratings = html_soup.find_all('td', class_ = 'average')
print(type(movie_ratings))
print(len(movie_ratings))
# Out:
# <class 'bs4.element.ResultSet'>
# 300

# %%
##aggregating data: fans number

# %%
fans_number = html_soup.find_all('td', class_ = 'count')
print(type(fans_number))
print(len(fans_number))
# Out:
# <class 'bs4.element.ResultSet'>
# 300

# %%
##aggregating data: order of the films

# %%
favourite_order = html_soup.find_all('td', class_ = 'order')
print(type(favourite_order))
print(len(favourite_order))
# Out:
# <class 'bs4.element.ResultSet'>
# 300

# %%
## Lists to store the scraped data in
names = []
years = []
csfd_ratings = []
fans = []

for container in movie_containers:
    
       # name of the film
        name = container.a.text
        names.append(name)
        # release year
        year = container.find('span', class_ = 'film-year').text
        years.append(year)

# %%
for container in movie_ratings:
        # The CSFD rating
        csfd = container.text
        csfd_ratings.append(csfd)

# %%
for container in fans_number:
        # The number of fans
        fan = container.text
        fans.append(fan)

# %%
#table creation

# %%
import pandas as pd
movie_ratings = pd.DataFrame({'Movie': names,
                       'Year': years,
                       'CSFD rating': csfd_ratings,
                      'Fans number': fans
                       })
print(movie_ratings.info())
movie_ratings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
# Movie          300 non-null object
# Year           300 non-null object
# CSFD rating    300 non-null object
# Fans number    300 non-null object
# dtypes: object(4)
# memory usage: 9.5+ KB
# None
#                                  Movie    Year CSFD rating     Fans number
# 0                         Forrest Gump  (1994)       94,5%  19327 fanoušků
# 1        Vykoupení z věznice Shawshank  (1994)       95,3%  17952 fanoušků
# 2    Pulp Fiction: Historky z podsvětí  (1994)       90,6%  16022 fanoušků
# 3                          Temný rytíř  (2008)       90,2%  10887 fanoušků
# 4    Pán prstenů: Společenstvo Prstenu  (2001)       90,4%  10058 fanoušků
# 5                              Počátek  (2010)       88,6%   9084 fanoušků
# 6                          Zelená míle  (1999)       92,8%   8409 fanoušků
# 7                               Matrix  (1999)       90,1%   8201 fanoušků
# 8            Pán prstenů: Návrat krále  (2003)       90,3%   8119 fanoušků
# 9                              Pelíšky  (1999)       91,2%   7008 fanoušků
# 10                               Kmotr  (1972)       91,8%   6880 fanoušků
# 11                       Nedotknutelní  (2011)       91,4%   6858 fanoušků
# 12                          Klub rváčů  (1999)       88,1%   6200 fanoušků
# 13                                Sedm  (1995)       92,3%   5993 fanoušků
# 14               Pán prstenů: Dvě věže  (2002)       88,3%   5591 fanoušků
# 15                              Avatar  (2009)       82,3%   5206 fanoušků
# 16         Přelet nad kukaččím hnízdem  (1975)       92,6%   4810 fanoušků
# 17                           Gladiátor  (2000)       88,3%   4789 fanoušků
# 18                       Láska nebeská  (2003)       85,8%   4703 fanoušků
# 19                         Gran Torino  (2008)       90,3%   4686 fanoušků
# 20         Terminátor 2: Den zúčtování  (1991)       90,7%   4628 fanoušků
# 21                            Avengers  (2012)       82,6%   4488 fanoušků
# 22                      Requiem za sen  (2000)       87,6%   4461 fanoušků
# 23                   Hanebný pancharti  (2009)       86,2%   4309 fanoušků
# 24                 Amélie z Montmartru  (2001)       84,8%   4183 fanoušků
# 25                      Americká krása  (1999)       87,4%   4056 fanoušků
# 26                        Interstellar  (2014)       84,1%   3982 fanoušků
# 27                   Nespoutaný Django  (2012)       87,8%   3666 fanoušků
# 28                       Dokonalý trik  (2006)       87,8%   3504 fanoušků
# 29                  Schindlerův seznam  (1993)       92,4%   3491 fanoušků
# ..                                 ...     ...         ...             ...
# 270                           Čokoláda  (2000)       79,8%    646 fanoušků
# 271            REVENANT Zmrtvýchvstání  (2015)       79,9%    646 fanoušků
# 272                       Obecná škola  (1991)       89,0%    645 fanoušků
# 273                          Gravitace  (2013)       78,0%    643 fanoušků
# 274                      Bournův mýtus  (2004)       85,7%    638 fanoušků
# 275                          60 sekund  (2000)       70,2%    635 fanoušků
# 276                    Matrix Reloaded  (2003)       77,5%    633 fanoušků
# 277                             Marťan  (2015)       82,4%    627 fanoušků
# 278                 Lepší už to nebude  (1997)       85,3%    626 fanoušků
# 279                         Zombieland  (2009)       75,8%    625 fanoušků
# 280                      Resident Evil  (2002)       69,0%    625 fanoušků
# 281                          Lásky čas  (2013)       81,3%    624 fanoušků
# 282                         Mary a Max  (2009)       84,7%    623 fanoušků
# 283                 The Social Network  (2010)       80,7%    623 fanoušků
# 284                         Mamma Mia!  (2008)       63,1%    622 fanoušků
# 285                          Podfukáři  (2013)       75,5%    621 fanoušků
# 286                    Dannyho parťáci  (2001)       82,7%    619 fanoušků
# 287                             Psycho  (1960)       87,9%    614 fanoušků
# 288                      Walk the Line  (2005)       83,6%    613 fanoušků
# 289                           Magnolia  (1999)       83,4%    611 fanoušků
# 290                     Krvavý diamant  (2006)       84,1%    607 fanoušků
# 291                     Trestná lavice  (2005)       75,1%    606 fanoušků
# 292           Černá kočka, bílý kocour  (1998)       83,8%    605 fanoušků
# 293                    Nezapomeň na mě  (2010)       75,3%    605 fanoušků
# 294                      Kmotr 1, 2, 3  (1992)       96,1%    602 fanoušků
# 295                      Interstate 60  (2002)       83,6%    601 fanoušků
# 296                        Já, padouch  (2010)       79,1%    600 fanoušků
# 297         Sherlock Holmes: Hra stínů  (2011)       75,0%    600 fanoušků
# 298    Walter Mitty a jeho tajný život  (2013)       77,0%    598 fanoušků
# 299                Grandhotel Budapešť  (2014)       79,7%    595 fanoušků
#
# [300 rows x 4 columns]

# %%
#examing the data and cleaning the data
movie_ratings['Year'].unique()
# Out:
# array(['(1994)', '(2008)', '(2001)', '(2010)', '(1999)', '(2003)',
#        '(1972)', '(2011)', '(1995)', '(2002)', '(2009)', '(1975)',
#        '(2000)', '(1991)', '(2012)', '(2014)', '(2006)', '(1993)',
#        '(1979)', '(2005)', '(1998)', '(2007)', '(1997)', '(1968)',
#        '(1996)', '(1977)', '(1980)', '(2013)', '(2004)', '(1986)',
#        '(1985)', '(1971)', '(1987)', '(1966)', '(1976)', '(1984)',
#        '(1983)', '(2016)', '(1988)', '(1990)', '(1974)', '(1982)',
#        '(1957)', '(1989)', '(2018)', '(1992)', '(2015)', '(1981)',
#        '(1961)', '(1959)', '(1953)', '(2019)', '(1960)', '(1973)',
#        '(2017)', '(1969)'], dtype=object)

# %%
movie_ratings['CSFD rating'].unique()
# Out:
# array(['94,5%', '95,3%', '90,6%', '90,2%', '90,4%', '88,6%', '92,8%',
#        '90,1%', '90,3%', '91,2%', '91,8%', '91,4%', '88,1%', '92,3%',
#        '88,3%', '82,3%', '92,6%', '85,8%', '90,7%', '82,6%', '87,6%',
#        '86,2%', '84,8%', '87,4%', '84,1%', '87,8%', '92,4%', '84,4%',
#        '87,9%', '89,6%', '87,3%', '89,1%', '85,7%', '88,0%', '86,3%',
#        '87,0%', '81,1%', '89,7%', '84,6%', '83,5%', '89,5%', '81,9%',
#        '86,9%', '81,6%', '84,0%', '89,3%', '82,8%', '86,7%', '86,4%',
#        '88,2%', '83,6%', '88,8%', '77,2%', '77,4%', '78,2%', '82,7%',
#        '80,1%', '84,7%', '90,0%', '86,5%', '85,1%', '87,2%', '88,7%',
#        '79,8%', '80,9%', '78,8%', '80,7%', '66,6%', '86,8%', '84,2%',
#        '81,0%', '88,4%', '86,1%', '78,4%', '90,9%', '81,4%', '89,0%',
#        '81,7%', '77,0%', '83,0%', '87,1%', '80,2%', '78,7%', '86,6%',
#        '89,4%', '77,5%', '77,7%', '79,0%', '79,6%', '80,4%', '80,8%',
#        '85,5%', '51,9%', '80,6%', '72,2%', '73,2%', '87,5%', '80,0%',
#        '88,9%', '82,9%', '79,7%', '83,9%', '85,0%', '73,8%', '76,4%',
#        '74,5%', '79,1%', '82,2%', '89,9%', '79,9%', '83,3%', '85,6%',
#        '84,9%', '84,5%', '76,2%', '82,1%', '75,4%', '76,7%', '75,1%',
#        '82,0%', '77,9%', '74,6%', '72,3%', '85,4%', '86,0%', '78,3%',
#        '73,3%', '69,5%', '79,3%', '64,7%', '81,3%', '85,3%', '71,7%',
#        '76,3%', '71,6%', '83,7%', '89,2%', '82,5%', '72,7%', '85,9%',
#        '77,8%', '70,7%', '75,9%', '74,1%', '81,8%', '78,0%', '70,2%',
#        '82,4%', '75,8%', '69,0%', '63,1%', '75,5%', '83,4%', '83,8%',
#        '75,3%', '96,1%', '75,0%'], dtype=object)

# %%
#removing %
movie_ratings.loc[:, 'CSFD rating'] = movie_ratings['CSFD rating'].str.strip('%')

# %%
#as float
movie_ratings.loc[:, 'CSFD rating'] = movie_ratings['CSFD rating'].str.replace(',','.').astype(float)

# %%
movie_ratings['CSFD rating'].head(3)
# Out:
# 0    94.5
# 1    95.3
# 2    90.6
# Name: CSFD rating, dtype: float64

# %%
#year as float
movie_ratings.loc[:, 'Year'] = movie_ratings['Year'].str[-5:-1].astype(int)

# %%
movie_ratings['Year'].head(3)
# Out:
# 0    1994
# 1    1994
# 2    1994
# Name: Year, dtype: int64

# %%
#removing 'fanoušků'
movie_ratings.loc[:, 'Fans number'] = movie_ratings['Fans number'].str.strip('fanoušků')

# %%
movie_ratings['Fans number'].head(3)
# Out:
# 0    19327
# 1    17952
# 2    16022
# Name: Fans number, dtype: object

# %%
#as integer
movie_ratings.loc[:, 'Fans number'] = movie_ratings['Fans number'].astype(int)

# %%
movie_ratings['Fans number'].head(3)
# Out:
# 0    19327
# 1    17952
# 2    16022
# Name: Fans number, dtype: int64

# %%
movie_ratings.describe().loc[['min', 'max'], ['CSFD rating', 'Fans number', 'Year']]
# Out:
#      CSFD rating  Fans number    Year
# min         51.9        595.0  1953.0
# max         96.1      19327.0  2019.0

# %%
#Hence from the top ranked 300 films, the best CSFD rating is 96.1% and lowest is 51.9%.

# %% [markdown]
# #### Now, we need to obtain data from IMDB page

# %% [markdown]
# In order for us to have the most comparable list of fims from IMDB page with respect to CSFD page, we employ advanced search.
# From the CSFD list we know, that the oldest film in the top rated films list is from 1953, hence we contrain the IMDB search to an interval 1.1.1953 - 1.1.2019.
# Furthermore, the list is sorted by the number of votes and in a descending order.

# %% [markdown]
# IMDB page offers not only IMDB rating but also Metascore rating. The IMDb score is generated by the IMDb users' ratings while the Metascore ratings are the scores from the website Metacritic.com. Scores are given by movie critics and the weighted score is assigned to a film. Hence, we employ both of these ratings for further comparison.

# %%
from requests import get
url3 = 'https://www.imdb.com/search/title?release_date=1953-01-01,2019-01-01&sort=num_votes,desc&start=01&ref_=adv_nxt'
response = get(url3)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle"

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
movie_containers3 = html_soup.find_all('div', class_ = 'lister-item mode-advanced')
print(type(movie_containers3))
print(len(movie_containers3))
# Out:
# <class 'bs4.element.ResultSet'>
# 50

# %%
#First 50 movies
# Lists to store the scraped data in
names3 = []
years3 = []
imdb_ratings3 = []
metascores3 = []
votes3 = []

for container in movie_containers3:
# If the movie has Metascore, then extract:
       if container.find('div', class_ = 'ratings-metascore') is not None:
# The name
        name3 = container.h3.a.text
        names3.append(name3)
# The year
        year3 = container.h3.find('span', class_ = 'lister-item-year').text
        years3.append(year3)
# The IMDB rating
        imdb3 = float(container.strong.text)
        imdb_ratings3.append(imdb3)
# The Metascore
        m_score3 = container.find('span', class_ = 'metascore').text
        metascores3.append(int(m_score3))
# The number of votes
        vote3 = container.find('span', attrs = {'name':'nv'})['data-value']
        votes3.append(int(vote3))

# %%
import pandas as pd
test_df3 = pd.DataFrame({'Movie': names3,
'Year': years3,
'IMDB rating': imdb_ratings3,
'Metascore': metascores3,
'Number of votes': votes3
})
print(test_df3.info())
test_df3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
# Movie              48 non-null object
# Year               48 non-null object
# IMDB rating        48 non-null float64
# Metascore          48 non-null int64
# Number of votes    48 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.0+ KB
# None
#                                        Movie    Year  IMDB rating  Metascore  \
# 0              Vykoupení z věznice Shawshank  (1994)          9.3         80
# 1                                Temný rytíř  (2008)          9.0         84
# 2                                    Počátek  (2010)          8.8         74
# 3                                 Klub rváčů  (1999)          8.8         66
# 4          Pulp Fiction: Historky z podsvětí  (1994)          8.9         94
# 5                               Forrest Gump  (1994)          8.8         82
# 6          Pán prstenů: Společenstvo prstenu  (2001)          8.8         92
# 7                                     Matrix  (1999)          8.7         73
# 8                  Pán prstenů: Návrat krále  (2003)          8.9         94
# 9                                      Kmotr  (1972)          9.2        100
# 10                       Temný rytíř povstal  (2012)          8.4         78
# 11                     Pán prstenů: Dvě věže  (2002)          8.7         87
# 12                              Interstellar  (2014)          8.6         74
# 13                                      Sedm  (1995)          8.6         65
# 14                                 Gladiátor  (2000)          8.5         67
# 15                         Nespoutaný Django  (2012)          8.4         81
# 16                             Batman začíná  (2005)          8.2         70
# 17                                  Avengers  (2012)          8.1         69
# 18                           Mlčení jehňátek  (1991)          8.6         85
# 19             Hvězdné války IV: Nová naděje  (1977)          8.6         90
# 20                         Hanebný pancharti  (2009)          8.3         69
# 21                    Zachraňte vojína Ryana  (1998)          8.6         91
# 22                        Schindlerův seznam  (1993)          8.9         93
# 23                           Skrytá identita  (2006)          8.5         85
# 24                             Dokonalý trik  (2006)          8.5         66
# 25      Hvězdné války V: Impérium vrací úder  (1980)          8.7         82
# 26                                    Avatar  (2009)          7.8         83
# 27                         Vlk z Wall Street  (2013)          8.2         75
# 28                                   Memento  (2000)          8.5         80
# 29                               Zelená míle  (1999)          8.6         61
# 30                           Prokletý ostrov  (2010)          8.1         63
# 31                                  Kmotr II  (1974)          9.0         90
# 32                            Americká krása  (1999)          8.4         86
# 33  Piráti z Karibiku - Prokletí Černé perly  (2003)          8.0         63
# 34                                   Titanic  (1997)          7.8         75
# 35                            V jako Vendeta  (2005)          8.2         62
# 36                       Kult hákového kříže  (1998)          8.5         62
# 37                           Strážci Galaxie  (2014)          8.1         76
# 38                     Návrat do budoucnosti  (1985)          8.5         87
# 39                                      Léon  (1994)          8.6         64
# 40               Terminátor 2: Den zúčtování  (1991)          8.5         75
# 41                         Obvyklí podezřelí  (1995)          8.6         77
# 42                                    Vall-I  (2008)          8.4         95
# 43                                   Mafiáni  (1990)          8.7         89
# 44                                 Kill Bill  (2003)          8.1         69
# 45                            Statečné srdce  (1995)          8.4         68
# 46                             Hledá se Nemo  (2003)          8.1         90
# 47                                  Iron Man  (2008)          7.9         79
#
#     Number of votes
# 0           2099405
# 1           2065731
# 2           1839915
# 3           1678508
# 4           1641585
# 5           1611139
# 6           1510412
# 7           1508545
# 8           1494551
# 9           1441262
# 10          1387121
# 11          1351437
# 12          1298306
# 13          1287892
# 14          1212517
# 15          1210716
# 16          1193928
# 17          1182987
# 18          1134066
# 19          1121841
# 20          1119486
# 21          1111255
# 22          1088730
# 23          1076068
# 24          1065856
# 25          1052697
# 26          1044511
# 27          1034602
# 28          1031161
# 29          1015839
# 30          1005288
# 31          1001794
# 32           990618
# 33           964098
# 34           956092
# 35           951984
# 36           951758
# 37           947469
# 38           936319
# 39           925944
# 40           908594
# 41           907598
# 42           906644
# 43           906519
# 44           905440
# 45           891672
# 46           866913
# 47           863814

# %% [markdown]
# As not every film has metascore, in order to have films with both of these ratings, we exclude those who do not have the metascore.

# %%
interval = [str(i) for i in [1,51,101,151,201,251,301]]

# %%
#Apparently, IMDB translates some films' names into Czech. 
#As not all films are translated, we will keep this list of films in English language.
headers = {"Accept-Language": "en-US, en;q=0.5"}

# %% [markdown]
# IMDB offers only 50 outputs per page.
# Thus we need to employ loop function in order to have a relatively same number of observations from both servers.
# Next step takes approximately 3mins for computer to process.

# %%
from time import time

# %%
# The lists to store data in
names3 = []
years3 = []
imdb_ratings3 = []
metascores3 = []
votes3 = []

#The loop
start_time = time()
requests = 0

for start in interval:

        # Get request
        response = get('https://www.imdb.com/search/title?release_date=1953-01-01,2019-01-01&sort=num_votes,desc&start=' + start, headers = headers)
        
        page_html = BeautifulSoup(response.text, 'html.parser')

        # Selected all the 50 movie containers from a single page
        mv_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')

        for container in mv_containers:
           # # If the movie has a Metascore, then:
            if container.find('div', class_ = 'ratings-metascore') is not None:

                # Scrape the name
                name3 = container.h3.a.text
                names3.append(name3)

                # Scrape the year
                year3 = container.h3.find('span', class_ = 'lister-item-year').text
                years3.append(year3)

                # Scrape the IMDB rating
                imdb3 = float(container.strong.text)
                imdb_ratings3.append(imdb3)

                # Scrape the Metascore
                m_score3 = container.find('span', class_ = 'metascore').text
                metascores3.append(int(m_score3))

                # Scrape the number of votes
                vote3 = container.find('span', attrs = {'name':'nv'})['data-value']
                votes3.append(int(vote3))

# %%
#list
movie_ratings3 = pd.DataFrame({'Movie': names3,
'Year': years3,
'IMDB rating': imdb_ratings3,
'Metascore': metascores3,
'Number of votes': votes3
})
print(movie_ratings3.info())
movie_ratings3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 5 columns):
# Movie              335 non-null object
# Year               335 non-null object
# IMDB rating        335 non-null float64
# Metascore          335 non-null int64
# Number of votes    335 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 13.2+ KB
# None
#                                                  Movie        Year  \
# 0                             The Shawshank Redemption      (1994)
# 1                                      The Dark Knight      (2008)
# 2                                            Inception      (2010)
# 3                                           Fight Club      (1999)
# 4                                         Pulp Fiction      (1994)
# 5                                         Forrest Gump      (1994)
# 6    The Lord of the Rings: The Fellowship of the Ring      (2001)
# 7                                           The Matrix      (1999)
# 8        The Lord of the Rings: The Return of the King      (2003)
# 9                                        The Godfather      (1972)
# 10                               The Dark Knight Rises      (2012)
# 11               The Lord of the Rings: The Two Towers      (2002)
# 12                                        Interstellar      (2014)
# 13                                               Se7en      (1995)
# 14                                           Gladiator      (2000)
# 15                                    Django Unchained      (2012)
# 16                                       Batman Begins      (2005)
# 17                                        The Avengers      (2012)
# 18                            The Silence of the Lambs      (1991)
# 19                  Star Wars: Episode IV - A New Hope      (1977)
# 20                                Inglourious Basterds      (2009)
# 21                                 Saving Private Ryan      (1998)
# 22                                    Schindler's List      (1993)
# 23                                        The Departed      (2006)
# 24                                        The Prestige      (2006)
# 25      Star Wars: Episode V - The Empire Strikes Back      (1980)
# 26                                              Avatar      (2009)
# 27                             The Wolf of Wall Street      (2013)
# 28                                             Memento      (2000)
# 29                                      The Green Mile      (1999)
# ..                                                 ...         ...
# 305                                  Quantum of Solace      (2008)
# 306                                  Blade Runner 2049      (2017)
# 307                                Lost in Translation      (2003)
# 308                                  The Da Vinci Code      (2006)
# 309                                  We're the Millers      (2013)
# 310                                  Gangs of New York      (2002)
# 311                              Live Free or Die Hard      (2007)
# 312                                         Big Hero 6      (2014)
# 313                                         Armageddon      (1998)
# 314                                   The Last Samurai      (2003)
# 315                                 Dead Poets Society      (1989)
# 316                                          The Mummy      (1999)
# 317                                          King Kong      (2005)
# 318                                  American Gangster      (2007)
# 319                                      Hacksaw Ridge      (2016)
# 320                     Transformers: Dark of the Moon      (2011)
# 321                                            Tangled      (2010)
# 322                                       The Terminal      (2004)
# 323            Fantastic Beasts and Where to Find Them      (2016)
# 324                Transformers: Revenge of the Fallen      (2009)
# 325                                          Spotlight  (I) (2015)
# 326                             The 40-Year-Old Virgin      (2005)
# 327                                        Baby Driver      (2017)
# 328                           The Theory of Everything      (2014)
# 329                                          In Bruges      (2008)
# 330                                    This Is the End      (2013)
# 331                        Back to the Future Part III      (1990)
# 332                                Mission: Impossible      (1996)
# 333                                Alice in Wonderland  (I) (2010)
# 334                                                 It  (I) (2017)
#
#      IMDB rating  Metascore  Number of votes
# 0            9.3         80          2099405
# 1            9.0         84          2065731
# 2            8.8         74          1839915
# 3            8.8         66          1678508
# 4            8.9         94          1641585
# 5            8.8         82          1611139
# 6            8.8         92          1510412
# 7            8.7         73          1508545
# 8            8.9         94          1494551
# 9            9.2        100          1441262
# 10           8.4         78          1387121
# 11           8.7         87          1351437
# 12           8.6         74          1298306
# 13           8.6         65          1287892
# 14           8.5         67          1212517
# 15           8.4         81          1210716
# 16           8.2         70          1193928
# 17           8.1         69          1182987
# 18           8.6         85          1134066
# 19           8.6         90          1121841
# 20           8.3         69          1119486
# 21           8.6         91          1111255
# 22           8.9         93          1088730
# 23           8.5         85          1076068
# 24           8.5         66          1065856
# 25           8.7         82          1052697
# 26           7.8         83          1044511
# 27           8.2         75          1034602
# 28           8.5         80          1031161
# 29           8.6         61          1015839
# ..           ...        ...              ...
# 305          6.6         58           377567
# 306          8.0         81           375836
# 307          7.8         89           374329
# 308          6.6         46           372064
# 309          7.0         44           371631
# 310          7.5         72           371387
# 311          7.1         69           371076
# 312          7.8         74           370908
# 313          6.7         42           370616
# 314          7.7         55           370155
# 315          8.1         79           369312
# 316          7.0         48           367087
# 317          7.2         81           366959
# 318          7.8         76           366831
# 319          8.1         71           366536
# 320          6.2         42           366291
# 321          7.8         71           366137
# 322          7.3         55           365661
# 323          7.3         66           365030
# 324          6.0         35           364889
# 325          8.1         93           364799
# 326          7.1         73           364388
# 327          7.6         86           363230
# 328          7.7         72           361288
# 329          7.9         67           361181
# 330          6.6         67           360418
# 331          7.4         55           359098
# 332          7.1         59           358940
# 333          6.5         53           358662
# 334          7.4         69           358524
#
# [335 rows x 5 columns]

# %%
##now, we need to clean the data

# %%
#year to integer

# %%
movie_ratings3.loc[:, 'Year'] = movie_ratings3['Year'].str[-5:-1].astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-9181892596e8> in <module>()
# ----> 1 movie_ratings3.loc[:, 'Year'] = movie_ratings3['Year'].str[-5:-1].astype(int)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
#     133         # Replace the property with the accessor object. Inspired by:
#     134         # http://www.pydanny.com/cached-property.html
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/strings.py in _validate(data)
#    1915             # (instead of test for object dtype), but that isn't practical for
#    1916             # performance reasons until we have a str dtype (GH 9343)
# -> 1917             raise AttributeError("Can only use .str accessor with string "
#    1918                                  "values, which use np.object_ dtype in "
#    1919                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
movie_ratings3['Year'].head(3)
# Out:
# 0    1994
# 1    2008
# 2    2010
# Name: Year, dtype: int64

# %%
#normalizing IMDB rating so they are comparable with CSFD rating and Metascore

# %%
movie_ratings3['Normalized IMDB rating'] = movie_ratings3['IMDB rating'] * 10

# %%
movie_ratings3.head(5)
# Out:
#                       Movie  Year  IMDB rating  Normalized IMDB rating  \
# 0  The Shawshank Redemption  1994          9.3                    93.0
# 1           The Dark Knight  2008          9.0                    90.0
# 2                 Inception  2010          8.8                    88.0
# 3                Fight Club  1999          8.8                    88.0
# 4              Pulp Fiction  1994          8.9                    89.0
#
#    Metascore  Number of votes
# 0         80          2099405
# 1         84          2065731
# 2         74          1839915
# 3         66          1678508
# 4         94          1641585

# %%
#reordering the columns
movie_ratings3 = movie_ratings3[['Movie', 'Year', 'IMDB rating','Normalized IMDB rating', 'Metascore', 'Number of votes']]

# %%
movie_ratings3.head(5)
# Out:
#                       Movie  Year  IMDB rating  Normalized IMDB rating  \
# 0  The Shawshank Redemption  1994          9.3                    93.0
# 1           The Dark Knight  2008          9.0                    90.0
# 2                 Inception  2010          8.8                    88.0
# 3                Fight Club  1999          8.8                    88.0
# 4              Pulp Fiction  1994          8.9                    89.0
#
#    Metascore  Number of votes
# 0         80          2099405
# 1         84          2065731
# 2         74          1839915
# 3         66          1678508
# 4         94          1641585

# %%
#####Visualisation of data and analysis#####

# %%
###First comparing distributions of IMDB rating and Metascore
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4))
ax1, ax2, ax3 = fig.axes
ax1.hist(movie_ratings3['IMDB rating'], bins = 10, range = (0,10))
ax1.set_title('IMDB rating')
ax2.hist(movie_ratings3['Metascore'], bins = 10, range = (0,100)) 
ax2.set_title('Metascore')
ax3.hist(movie_ratings3['Normalized IMDB rating'], bins = 10, range = (0,100), histtype = 'step')
ax3.hist(movie_ratings3['Metascore'], bins = 10, range = (0,100), histtype = 'step')
ax3.legend(loc = 'upper left')
ax3.set_title('The Two Normalized Distributions')
for ax in fig.axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.show()

# %%
#Secondly, comparing distributions of CSFD rating and IMDB rating

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4))
ax4, ax5, ax6 = fig.axes
ax4.hist(movie_ratings3['IMDB rating'], bins = 10, range = (0,10)) 
ax4.set_title('IMDB rating')
ax5.hist(movie_ratings['CSFD rating'], bins = 10, range = (0,100)) 
ax5.set_title('CSFD rating')
ax6.hist(movie_ratings3['Normalized IMDB rating'], bins = 10, range = (40,100), histtype = 'step')
ax6.hist(movie_ratings['CSFD rating'], bins = 10, range = (40,100), histtype = 'step')
ax6.legend(loc = 'upper left')
ax6.set_title('The Two Normalized Distributions')
for ax in fig.axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# Interpretation of the last historgram must be done carefully, as there are different films in both data sets.
# Nevertheless, in general, the results suggest that the IMDB users tend to be more critical in the ratings of the films.

# %%
#Lastly, comparing distribution of CSFD rating and Metascore

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4))
ax7, ax8, ax9 = fig.axes
ax7.hist(movie_ratings3['Metascore'], bins = 10, range = (0,100)) 
ax7.set_title('Metascore')
ax8.hist(movie_ratings['CSFD rating'], bins = 10, range = (0,100)) 
ax8.set_title('CSFD rating')
ax9.hist(movie_ratings3['Metascore'], bins = 10, range = (40,100), histtype = 'step')
ax9.hist(movie_ratings['CSFD rating'], bins = 10, range = (40,100), histtype = 'step')
ax9.legend(loc = 'upper left')
ax9.set_title('The Two Normalized Distributions')
for ax in fig.axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
##Relationship of Year and Rating
plt.figure(figsize=[30,10], dpi=100)
sns.barplot(x='Year', y='IMDB rating', data=movie_ratings3)

# %%
#Relationship between Rating and number of votes for IMDB
plt.scatter(movie_ratings3['Number of votes'], movie_ratings3['IMDB rating'])

#axis labels
plt.xlabel('Number of votes')
plt.ylabel('IMDB rating')

# set axis limits
plt.xlim([250000, 2125000])
plt.ylim([5, 10])
plt.title('Number of votes vs. IMDB rating')
# Out:
# Text(0.5,1,'Number of votes vs. IMDB rating')

# %%
#Relationship between CSFD rating and number of fans
plt.scatter(movie_ratings['Fans number'], movie_ratings['CSFD rating'])

#axis labels
plt.xlabel('Number of fans')
plt.ylabel('CSFD rating')

# set axis limits
plt.xlim([0, 20000])
plt.ylim([45, 100])
plt.title('Fans number vs. CSFD rating')
# Out:
# Text(0.5,1,'Fans number vs. CSFD rating')

# %% [markdown]
# Now we analyze a subset of the same films from both servers. From CSFD webpage we obtain Czech names of the films, while from IMDB webpage we get English names of the films. Hence, are not able to compare the lists to find the same names by code, we must do it mannualy. For our analysis we select 20 movies which present in both lists.

# %%
x = movie_ratings3[movie_ratings3['Movie'].isin(['Inception', 'Fight Club', 'Pulp Fiction','Forrest Gump', 'The Shawshank Redemption', 'The Godfather','The Avengers','Saving Private Ryan', 'The Prestige','Avatar'])]

# %%
x
# Out:
#                        Movie  Year  IMDB rating  Normalized IMDB rating  \
# 0   The Shawshank Redemption  1994          9.3                    93.0
# 2                  Inception  2010          8.8                    88.0
# 3                 Fight Club  1999          8.8                    88.0
# 4               Pulp Fiction  1994          8.9                    89.0
# 5               Forrest Gump  1994          8.8                    88.0
# 9              The Godfather  1972          9.2                    92.0
# 17              The Avengers  2012          8.1                    81.0
# 21       Saving Private Ryan  1998          8.6                    86.0
# 24              The Prestige  2006          8.5                    85.0
# 26                    Avatar  2009          7.8                    78.0
#
#     Metascore  Number of votes
# 0          80          2099405
# 2          74          1839915
# 3          66          1678508
# 4          94          1641585
# 5          82          1611139
# 9         100          1441262
# 17         69          1182987
# 21         91          1111255
# 24         66          1065856
# 26         83          1044511

# %%
m = movie_ratings[movie_ratings['Movie'].isin(['Avatar', 'Počátek','Klub rváčů','Pulp Fiction: Historky z podsvětí','Forrest Gump', 'Vykoupení z věznice Shawshank', 'Kmotr','Avengers','Zachraňte vojína Ryana','Dokonalý trik'])]

# %%
m
# Out:
#                                 Movie  Year  CSFD rating  Fans number
# 0                        Forrest Gump  1994         94.5        19327
# 1       Vykoupení z věznice Shawshank  1994         95.3        17952
# 2   Pulp Fiction: Historky z podsvětí  1994         90.6        16022
# 5                             Počátek  2010         88.6         9084
# 10                              Kmotr  1972         91.8         6880
# 12                         Klub rváčů  1999         88.1         6200
# 15                             Avatar  2009         82.3         5206
# 21                           Avengers  2012         82.6         4488
# 28                      Dokonalý trik  2006         87.8         3504
# 34             Zachraňte vojína Ryana  1998         89.1         3093

# %%
m.reindex([1,5,12,2,0,10,21,34,28,15])
# Out:
#                                 Movie  Year  CSFD rating  Fans number
# 1       Vykoupení z věznice Shawshank  1994         95.3        17952
# 5                             Počátek  2010         88.6         9084
# 12                         Klub rváčů  1999         88.1         6200
# 2   Pulp Fiction: Historky z podsvětí  1994         90.6        16022
# 0                        Forrest Gump  1994         94.5        19327
# 10                              Kmotr  1972         91.8         6880
# 21                           Avengers  2012         82.6         4488
# 34             Zachraňte vojína Ryana  1998         89.1         3093
# 28                      Dokonalý trik  2006         87.8         3504
# 15                             Avatar  2009         82.3         5206

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4))
ax10, ax11, ax12 = fig.axes
ax10.hist(x['IMDB rating'], bins = 10, range = (7,10)) 
ax10.set_title('IMDB rating')
ax11.hist(m['CSFD rating'], bins = 10, range = (70,100)) 
ax11.set_title('CSFD rating')
ax12.hist(x['Normalized IMDB rating'], bins = 10, range = (70,100), histtype = 'step')
ax12.hist(m['CSFD rating'], bins = 10, range = (70,100), histtype = 'step')
ax12.legend(loc = 'upper left')
ax12.set_title('The Two Normalized Distributions')
for ax in fig.axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# In these specific subsets, we have considered 10 movies of our own choice. All of them are very good movies, very well reviewed - that is the reason why we shrinked the plots to a range of 7 to 10 (there is no movie with a lower rating than 70%). We can see the differences in ratings pretty well on first two plots and the final comparison on the last plot. It seems, that people reviewing movies on IMDB are more sceptical, giving a lower rating to the identical movies.

# %%
import plotly as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-88-1d2353c546e3> in <module>()
# ----> 1 import plotly as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import sys
# !conda install --yes --prefix {sys.prefix} plotly
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/admin/anaconda3
#
#   added / updated specs:
#     - plotly
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libssh2-1.8.2              |       ha12b0ac_0         221 KB
#     libcurl-7.64.1             |       h051b688_0         546 KB
#     r-kernlab-0.9_26           |   r351h46e27c5_0         2.1 MB
#     r-rappdirs-0.3.1           |   r351h6402f54_0          96 KB
#     retrying-1.3.3             |           py36_2          15 KB
#     r-robustbase-0.93_2        |   r351h0b560c1_0         3.0 MB
#     r-packrat-0.4.9_3          |   r351hf348343_0         448 KB
#     r-ipred-0.9_6              |   r351h6402f54_0         383 KB
#     r-formatr-1.5              |   r351hf348343_0         150 KB
#     sqlite-3.28.0              |       ha441bb4_0         2.3 MB
#     r-viridislite-0.3.0        |   r351hf348343_0          63 KB
#     libedit-3.1.20181209       |       hb402a30_0         159 KB
#     r-forcats-0.3.0            |   r351hf348343_0         211 KB
#     r-colorspace-1.3_2         |   r351h6402f54_0         512 KB
#     r-assertthat-0.2.0         |   r351hf348343_0          57 KB
#     r-cli-1.0.0                |   r351h6115d3f_0         323 KB
#     r-codetools-0.2_15         |   r351hf348343_0          91 KB
#     unixodbc-2.3.7             |       h1de35cc_0         271 KB
#     r-glue-1.3.0               |   r351h6402f54_0          94 KB
#     r-lubridate-1.7.4          |   r351h32998d9_0         1.0 MB
#     r-rcpproll-0.3.0           |   r351h32998d9_0         107 KB
#     curl-7.64.1                |       ha441bb4_0         131 KB
#     r-rjdbc-0.2_7.1            |   r351hf348343_0         101 KB
#     r-tidyselect-0.2.4         |   r351h32998d9_0         118 KB
#     r-sparklyr-0.8.4           |   r351hf348343_0         2.7 MB
#     tk-8.6.8                   |       ha441bb4_0         3.2 MB
#     r-zoo-1.8_3                |   r351h6402f54_0         1.0 MB
#     r-rlang-0.2.1              |   r351h6402f54_0         768 KB
#     r-xts-0.11_0               |   r351h6402f54_0         896 KB
#     r-matrix-1.2_14            |   r351h6402f54_0         3.7 MB
#     r-highr-0.7                |   r351hf348343_0          46 KB
#     r-bitops-1.0_6             |   r351h6402f54_4          27 KB
#     r-bit-1.1_14               |   r351h6402f54_0         234 KB
#     r-cvst-0.2_2               |   r351hf348343_0          89 KB
#     r-repr-0.15.0              |   r351hf348343_0         105 KB
#     r-evaluate-0.11            |   r351hf348343_0          76 KB
#     r-r6-2.2.2                 |   r351hf348343_0         275 KB
#     r-squarem-2017.10_1        |   r351hf348343_0         289 KB
#     r-nlme-3.1_137             |   r351h0b560c1_0         2.2 MB
#     r-pls-2.6_0                |   r351hf348343_0         1.2 MB
#     r-dbi-1.0.0                |   r351hf348343_0         873 KB
#     r-stringr-1.3.1            |   r351hf348343_0         184 KB
#     r-broom-0.5.0              |   r351hf348343_0         1.9 MB
#     r-gtable-0.2.0             |   r351hf348343_0          88 KB
#     r-mass-7.3_50              |   r351h6402f54_0         1.1 MB
#     freetype-2.9.1             |       hb4e5f40_0         864 KB
#     r-irkernel-0.8.12          |           r351_0         199 KB
#     r-dimred-0.1.0             |   r351hf348343_0         615 KB
#     r-class-7.3_14             |   r351h6402f54_4          93 KB
#     r-modelr-0.1.2             |   r351hf348343_0         199 KB
#     r-catools-1.17.1.1         |   r351h32998d9_0         214 KB
#     r-caret-6.0_80             |   r351h6402f54_0         5.9 MB
#     r-mgcv-1.8_24              |   r351h6402f54_0         2.5 MB
#     r-praise-1.0.0             |   r351hf348343_4          21 KB
#     r-digest-0.6.15            |   r351h6402f54_0         145 KB
#     r-htmltools-0.3.6          |   r351h32998d9_0         173 KB
#     r-irdisplay-0.5.0          |   r351hf348343_0          34 KB
#     r-gower-0.1.2              |   r351h6402f54_0          38 KB
#     r-dplyr-0.7.6              |   r351h32998d9_0         1.7 MB
#     r-cellranger-1.1.0         |   r351hf348343_0         105 KB
#     r-rematch-1.0.1            |   r351hf348343_0          18 KB
#     r-munsell-0.5.0            |   r351hf348343_0         242 KB
#     fontconfig-2.13.0          |       h5d5b041_1         245 KB
#     r-withr-2.1.2              |   r351hf348343_0         161 KB
#     r-modelmetrics-1.1.0       |   r351h32998d9_0          94 KB
#     r-uuid-0.1_2               |   r351h6402f54_4          19 KB
#     r-lava-1.6.2               |   r351hf348343_0         2.2 MB
#     r-httpuv-1.4.5             |   r351h32998d9_0         416 KB
#     r-tinytex-0.6              |   r351hf348343_0          81 KB
#     r-prodlim-2018.04.18       |   r351h32998d9_0         396 KB
#     matplotlib-3.0.0           |   py36h54f8f79_0         6.8 MB
#     r-rsconnect-0.8.8          |   r351hf348343_0         496 KB
#     r-bindrcpp-0.2.2           |   r351h32998d9_0          79 KB
#     libopenblas-0.3.6          |       hdc02c5d_0         8.5 MB
#     r-rvest-0.3.2              |   r351hf348343_0         871 KB
#     r-pillar-1.3.0             |   r351hf348343_0         157 KB
#     r-openssl-1.0.2            |   r351h46e59ec_1         1.1 MB
#     fribidi-1.0.5              |       h1de35cc_0          62 KB
#     r-hms-0.4.2                |   r351hf348343_0          60 KB
#     r-foreach-1.4.4            |   r351hf348343_0         403 KB
#     r-reprex-0.2.0             |   r351hf348343_0         398 KB
#     r-timedate-3043.102        |   r351hf348343_0         1.5 MB
#     r-shiny-1.1.0              |   r351hf348343_0         3.2 MB
#     r-xml2-1.2.0               |   r351h32998d9_0         315 KB
#     r-ttr-0.23_3               |   r351h0b560c1_0         505 KB
#     cairo-1.14.12              |       hc4e6be7_4         1.2 MB
#     r-bit64-0.9_7              |   r351h6402f54_0         474 KB
#     r-rmarkdown-1.10           |   r351hf348343_0         2.4 MB
#     certifi-2019.3.9           |           py36_0         155 KB
#     r-markdown-0.8             |   r351h6402f54_0         135 KB
#     r-base-3.5.1               |       h539fb6c_1        40.0 MB
#     r-haven-1.1.2              |   r351h32998d9_0         289 KB
#     r-later-0.7.3              |   r351h32998d9_0          81 KB
#     r-miniui-0.1.1.1           |   r351hf348343_0          39 KB
#     python-3.6.8               |       haf84260_0        20.5 MB
#     pillow-5.4.1               |   py36hb68e598_0         584 KB
#     r-psych-1.8.4              |   r351hf348343_0         5.5 MB
#     r-rstudioapi-0.7           |   r351hf348343_0         133 KB
#     r-rprojroot-1.3_2          |   r351hf348343_0          82 KB
#     r-blob-1.1.1               |   r351hf348343_0          28 KB
#     r-boot-1.3_20              |   r351hf348343_0         624 KB
#     r-crayon-1.3.4             |   r351hf348343_0         745 KB
#     r-config-0.3               |   r351hf348343_0          28 KB
#     r-xtable-1.8_2             |   r351hf348343_0         749 KB
#     libdb-6.1.26               |       h0a44026_0        22.0 MB
#     notebook-5.7.8             |           py36_0         7.3 MB
#     r-pkgconfig-2.0.1          |   r351hf348343_0          23 KB
#     conda-4.6.14               |           py36_0         2.1 MB
#     r-maps-3.3.0               |   r351h6402f54_0         3.5 MB
#     r-processx-3.1.0           |   r351h32998d9_0         317 KB
#     pango-1.42.4               |       h060686c_0         523 KB
#     r-rcolorbrewer-1.1_2       |   r351hf348343_0          59 KB
#     r-stringi-1.2.4            |   r351h32998d9_0        11.5 MB
#     r-geometry-0.3_6           |   r351h6402f54_0         421 KB
#     r-rcpp-0.12.18             |   r351h32998d9_0         3.4 MB
#     r-readxl-1.1.0             |   r351h32998d9_0         786 KB
#     r-drr-0.0.3                |   r351hf348343_0         167 KB
#     r-selectr-0.4_1            |   r351hf348343_0         368 KB
#     r-mongolite-1.6            |   r351h46e59ec_1         331 KB
#     r-curl-3.2                 |   r351h6402f54_0         403 KB
#     r-magrittr-1.5             |   r351hf348343_4         165 KB
#     r-deoptimr-1.0_8           |   r351hf348343_0          45 KB
#     r-htmlwidgets-1.2          |   r351hf348343_0         692 KB
#     r-mime-0.5                 |   r351h6402f54_0          37 KB
#     r-dbplyr-1.2.2             |   r351hf348343_0         533 KB
#     r-survival-2.42_6          |   r351h6402f54_0         4.3 MB
#     krb5-1.16.1                |       hddcf347_7         1.1 MB
#     r-clipr-0.4.1              |   r351hf348343_0          40 KB
#     r-jsonlite-1.5             |   r351h6402f54_0         1.1 MB
#     r-spatial-7.3_11           |   r351h6402f54_4         141 KB
#     r-xfun-0.3                 |   r351hf348343_0         150 KB
#     r-fansi-0.2.3              |   r351h6402f54_0         130 KB
#     r-nnet-7.3_12              |   r351h6402f54_0         120 KB
#     r-recommended-3.5.1        |           r351_0           3 KB
#     harfbuzz-1.8.8             |       hb8d4a28_0         703 KB
#     r-tidyr-0.8.1              |   r351h32998d9_0         415 KB
#     r-bindr-0.1.1              |   r351hf348343_0          20 KB
#     r-ddalpha-1.3.4            |   r351h4496799_0         1.2 MB
#     r-pki-0.1_5.1              |   r351h46e59ec_1          95 KB
#     r-rjava-0.9_10             |   r351h6402f54_0         672 KB
#     r-callr-2.0.4              |   r351hf348343_0         136 KB
#     r-rpart-4.1_13             |   r351h6402f54_0         900 KB
#     r-magic-1.5_8              |   r351hf348343_0         579 KB
#     r-numderiv-2016.8_1        |   r351hf348343_0         117 KB
#     r-odbc-1.1.5               |   r351h0a44026_0         431 KB
#     r-rbokeh-0.6.3             |           r351_0         4.1 MB
#     r-plyr-1.8.4               |   r351h32998d9_0         811 KB
#     r-bh-1.66.0_1              |   r351hf348343_0        10.0 MB
#     r-promises-1.0.1           |   r351h32998d9_0         166 KB
#     r-profvis-0.3.5            |   r351h6402f54_0         164 KB
#     prometheus_client-0.6.0    |           py36_0          69 KB
#     r-kernsmooth-2.23_15       |   r351h0b560c1_4          95 KB
#     r-lazyeval-0.2.1           |   r351h6402f54_0         146 KB
#     r-foreign-0.8_71           |   r351h6402f54_0         255 KB
#     r-whisker-0.3_2            |   r351hf348343_4          66 KB
#     r-mnormt-1.5_5             |   r351h0b560c1_0          84 KB
#     r-sourcetools-0.1.7        |   r351h32998d9_0          48 KB
#     r-prettyunits-1.0.2        |   r351hf348343_0          35 KB
#     r-lattice-0.20_35          |   r351h6402f54_0         1.1 MB
#     r-testthat-2.0.0           |   r351h32998d9_0         956 KB
#     r-knitr-1.20               |   r351hf348343_0         1.0 MB
#     r-backports-1.1.2          |   r351h6402f54_0          45 KB
#     r-httr-1.3.1               |   r351hf348343_0         437 KB
#     cryptography-2.7           |   py36ha12b0ac_0         567 KB
#     r-glmnet-2.0_16            |   r351h0b560c1_0         1.4 MB
#     r-cluster-2.0.7_1          |   r351h0b560c1_0         534 KB
#     r-dichromat-2.0_0          |   r351hf348343_4         151 KB
#     r-utf8-1.1.4               |   r351h6402f54_0         154 KB
#     r-scales-0.5.0             |   r351h32998d9_0         299 KB
#     r-quantmod-0.4_13          |   r351hf348343_0         952 KB
#     ca-certificates-2019.5.15  |                0         133 KB
#     cyrus-sasl-2.1.26          |       hb48c43a_4         257 KB
#     r-reshape2-1.4.3           |   r351h32998d9_0         118 KB
#     r-essentials-3.5.1         |           r351_0           5 KB
#     pycurl-7.43.0.2            |   py36ha12b0ac_0         185 KB
#     r-ggplot2-3.0.0            |   r351hf348343_0         3.5 MB
#     r-rjsonio-1.3_0            |   r351h32998d9_4        1000 KB
#     openssl-1.1.1c             |       h1de35cc_1         3.4 MB
#     r-pbdzmq-0.3_3             |   r351h32998d9_0         387 KB
#     r-sfsmisc-1.1_2            |   r351hf348343_0         605 KB
#     r-abind-1.4_5              |   r351hf348343_0          66 KB
#     r-labeling-0.3             |   r351hf348343_4          64 KB
#     r-readr-1.1.1              |   r351h32998d9_0         587 KB
#     r-hexbin-1.27.2            |   r351h0b560c1_0         858 KB
#     r-base64enc-0.1_3          |   r351h6402f54_4          31 KB
#     r-data.table-1.11.4        |   r351h6402f54_0         1.4 MB
#     r-purrr-0.2.5              |   r351h6402f54_0         276 KB
#     r-recipes-0.1.3            |   r351hf348343_0         1.2 MB
#     r-tibble-1.4.2             |   r351h6402f54_0         227 KB
#     r-iterators-1.0.10         |   r351hf348343_0         334 KB
#     r-plogr-0.2.0              |   r351hf348343_0          18 KB
#     r-rcurl-1.95_4.11          |   r351h6402f54_0         858 KB
#     r-randomforest-4.6_14      |   r351h0b560c1_0         223 KB
#     plotly-3.10.0              |             py_0        22.9 MB
#     ncurses-6.1                |       h0a44026_1         887 KB
#     r-tidyverse-1.2.1          |   r351hf348343_0          92 KB
#     r-yaml-2.2.0               |   r351h6402f54_0         107 KB
#     make-4.2.1                 |       h3efe00b_1         234 KB
#     ------------------------------------------------------------
#                                            Total:       278.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     fribidi:           1.0.5-h1de35cc_0
#     libdb:             6.1.26-h0a44026_0
#     libopenblas:       0.3.6-hdc02c5d_0
#     make:              4.2.1-h3efe00b_1
#     plotly:            3.10.0-py_0
#     prometheus_client: 0.6.0-py36_0
#     r-abind:           1.4_5-r351hf348343_0
#     r-fansi:           0.2.3-r351h6402f54_0
#     r-geometry:        0.3_6-r351h6402f54_0
#     r-later:           0.7.3-r351h32998d9_0
#     r-magic:           1.5_8-r351hf348343_0
#     r-pls:             2.6_0-r351hf348343_0
#     r-praise:          1.0.0-r351hf348343_4
#     r-prettyunits:     1.0.2-r351hf348343_0
#     r-processx:        3.1.0-r351h32998d9_0
#     r-promises:        1.0.1-r351h32998d9_0
#     r-squarem:         2017.10_1-r351hf348343_0
#     r-testthat:        2.0.0-r351h32998d9_0
#     r-tinytex:         0.6-r351hf348343_0
#     r-xfun:            0.3-r351hf348343_0
#     retrying:          1.3.3-py36_2
#
# The following packages will be UPDATED:
#
#     ca-certificates:   2018.03.07-0             --> 2019.5.15-0
#     cairo:             1.14.12-he60d9cb_2       --> 1.14.12-hc4e6be7_4
#     certifi:           2018.8.24-py36_1         --> 2019.3.9-py36_0
#     conda:             4.5.11-py36_0            --> 4.6.14-py36_0
#     cryptography:      2.2.2-py36h1de35cc_0     --> 2.7-py36ha12b0ac_0
#     curl:              7.60.0-ha441bb4_0        --> 7.64.1-ha441bb4_0
#     cyrus-sasl:        2.1.26-ha054001_1        --> 2.1.26-hb48c43a_4
#     fontconfig:        2.12.6-h9850fc5_0        --> 2.13.0-h5d5b041_1
#     freetype:          2.8-h12048fb_1           --> 2.9.1-hb4e5f40_0
#     harfbuzz:          1.7.6-h171471c_1         --> 1.8.8-hb8d4a28_0
#     krb5:              1.14.2-h9a779f2_6        --> 1.16.1-hddcf347_7
#     libcurl:           7.60.0-hf30b1f0_0        --> 7.64.1-h051b688_0
#     libedit:           3.1-hb4e282d_0           --> 3.1.20181209-hb402a30_0
#     libssh2:           1.8.0-h322a93b_4         --> 1.8.2-ha12b0ac_0
#     matplotlib:        2.2.2-py36ha7267d0_0     --> 3.0.0-py36h54f8f79_0
#     ncurses:           6.0-hd04f020_2           --> 6.1-h0a44026_1
#     notebook:          5.5.0-py36_0             --> 5.7.8-py36_0
#     openssl:           1.0.2p-h1de35cc_0        --> 1.1.1c-h1de35cc_1
#     pango:             1.41.0-h3bae10e_0        --> 1.42.4-h060686c_0
#     pillow:            5.1.0-py36hfcce615_0     --> 5.4.1-py36hb68e598_0
#     pycurl:            7.43.0.1-py36hdbc3d79_0  --> 7.43.0.2-py36ha12b0ac_0
#     python:            3.6.5-hc167b69_1         --> 3.6.8-haf84260_0
#     r-assertthat:      0.2.0-r343h889e2dd_0     --> 0.2.0-r351hf348343_0
#     r-backports:       1.1.2-r343h7f474d2_0     --> 1.1.2-r351h6402f54_0
#     r-base:            3.4.3-h9b62496_0         --> 3.5.1-h539fb6c_1
#     r-base64enc:       0.1_3-r343h7f474d2_4     --> 0.1_3-r351h6402f54_4
#     r-bh:              1.65.0_1-r343h889e2dd_0  --> 1.66.0_1-r351hf348343_0
#     r-bindr:           0.1-r343h889e2dd_0       --> 0.1.1-r351hf348343_0
#     r-bindrcpp:        0.2-r343he124285_0       --> 0.2.2-r351h32998d9_0
#     r-bit:             1.1_12-r343h7f474d2_0    --> 1.1_14-r351h6402f54_0
#     r-bit64:           0.9_7-r343h7f474d2_0     --> 0.9_7-r351h6402f54_0
#     r-bitops:          1.0_6-r343h7f474d2_4     --> 1.0_6-r351h6402f54_4
#     r-blob:            1.1.0-r343h889e2dd_0     --> 1.1.1-r351hf348343_0
#     r-boot:            1.3_20-r343h889e2dd_0    --> 1.3_20-r351hf348343_0
#     r-broom:           0.4.3-r343h889e2dd_0     --> 0.5.0-r351hf348343_0
#     r-callr:           1.0.0-r343h889e2dd_0     --> 2.0.4-r351hf348343_0
#     r-caret:           6.0_78-r343h7f474d2_0    --> 6.0_80-r351h6402f54_0
#     r-catools:         1.17.1-r343he124285_4    --> 1.17.1.1-r351h32998d9_0
#     r-cellranger:      1.1.0-r343h889e2dd_0     --> 1.1.0-r351hf348343_0
#     r-class:           7.3_14-r343h7f474d2_4    --> 7.3_14-r351h6402f54_4
#     r-cli:             1.0.0-r343h889e2dd_0     --> 1.0.0-r351h6115d3f_0
#     r-clipr:           0.4.0-r343h889e2dd_0     --> 0.4.1-r351hf348343_0
#     r-cluster:         2.0.6-r343h883f7c5_0     --> 2.0.7_1-r351h0b560c1_0
#     r-codetools:       0.2_15-r343h889e2dd_0    --> 0.2_15-r351hf348343_0
#     r-colorspace:      1.3_2-r343h7f474d2_0     --> 1.3_2-r351h6402f54_0
#     r-config:          0.2-r343h889e2dd_0       --> 0.3-r351hf348343_0
#     r-crayon:          1.3.4-r343h889e2dd_0     --> 1.3.4-r351hf348343_0
#     r-curl:            3.1-r343h7f474d2_0       --> 3.2-r351h6402f54_0
#     r-cvst:            0.2_1-r343h889e2dd_0     --> 0.2_2-r351hf348343_0
#     r-data.table:      1.10.4_3-r343h7f474d2_0  --> 1.11.4-r351h6402f54_0
#     r-dbi:             0.7-r343h889e2dd_0       --> 1.0.0-r351hf348343_0
#     r-dbplyr:          1.1.0-r343h889e2dd_0     --> 1.2.2-r351hf348343_0
#     r-ddalpha:         1.3.1-r343h9f775be_0     --> 1.3.4-r351h4496799_0
#     r-deoptimr:        1.0_8-r343h889e2dd_0     --> 1.0_8-r351hf348343_0
#     r-dichromat:       2.0_0-r343h889e2dd_4     --> 2.0_0-r351hf348343_4
#     r-digest:          0.6.13-r343h7f474d2_0    --> 0.6.15-r351h6402f54_0
#     r-dimred:          0.1.0-r343h889e2dd_0     --> 0.1.0-r351hf348343_0
#     r-dplyr:           0.7.4-r343he124285_0     --> 0.7.6-r351h32998d9_0
#     r-drr:             0.0.2-r343h889e2dd_0     --> 0.0.3-r351hf348343_0
#     r-essentials:      3.4.3-r343_0             --> 3.5.1-r351_0
#     r-evaluate:        0.10.1-r343h889e2dd_0    --> 0.11-r351hf348343_0
#     r-forcats:         0.2.0-r343h889e2dd_0     --> 0.3.0-r351hf348343_0
#     r-foreach:         1.4.4-r343h889e2dd_0     --> 1.4.4-r351hf348343_0
#     r-foreign:         0.8_69-r343h7f474d2_0    --> 0.8_71-r351h6402f54_0
#     r-formatr:         1.5-r343h889e2dd_0       --> 1.5-r351hf348343_0
#     r-ggplot2:         2.2.1-r343h889e2dd_0     --> 3.0.0-r351hf348343_0
#     r-glmnet:          2.0_13-r343h883f7c5_0    --> 2.0_16-r351h0b560c1_0
#     r-glue:            1.2.0-r343h7f474d2_0     --> 1.3.0-r351h6402f54_0
#     r-gower:           0.1.2-r343h7f474d2_0     --> 0.1.2-r351h6402f54_0
#     r-gtable:          0.2.0-r343h889e2dd_0     --> 0.2.0-r351hf348343_0
#     r-haven:           1.1.0-r343he124285_0     --> 1.1.2-r351h32998d9_0
#     r-hexbin:          1.27.1-r343h883f7c5_4    --> 1.27.2-r351h0b560c1_0
#     r-highr:           0.6-r343h889e2dd_0       --> 0.7-r351hf348343_0
#     r-hms:             0.4.0-r343h889e2dd_0     --> 0.4.2-r351hf348343_0
#     r-htmltools:       0.3.6-r343he124285_0     --> 0.3.6-r351h32998d9_0
#     r-htmlwidgets:     0.9-r343h889e2dd_0       --> 1.2-r351hf348343_0
#     r-httpuv:          1.3.5-r343he124285_0     --> 1.4.5-r351h32998d9_0
#     r-httr:            1.3.1-r343h889e2dd_0     --> 1.3.1-r351hf348343_0
#     r-ipred:           0.9_6-r343h7f474d2_0     --> 0.9_6-r351h6402f54_0
#     r-irdisplay:       0.4.4-r343h889e2dd_0     --> 0.5.0-r351hf348343_0
#     r-irkernel:        0.8.11-r343_0            --> 0.8.12-r351_0
#     r-iterators:       1.0.9-r343h889e2dd_0     --> 1.0.10-r351hf348343_0
#     r-jsonlite:        1.5-r343h7f474d2_0       --> 1.5-r351h6402f54_0
#     r-kernlab:         0.9_25-r343h9f775be_0    --> 0.9_26-r351h46e27c5_0
#     r-kernsmooth:      2.23_15-r343h883f7c5_4   --> 2.23_15-r351h0b560c1_4
#     r-knitr:           1.18-r343h889e2dd_0      --> 1.20-r351hf348343_0
#     r-labeling:        0.3-r343h889e2dd_4       --> 0.3-r351hf348343_4
#     r-lattice:         0.20_35-r343h7f474d2_0   --> 0.20_35-r351h6402f54_0
#     r-lava:            1.5.1-r343h889e2dd_0     --> 1.6.2-r351hf348343_0
#     r-lazyeval:        0.2.1-r343h7f474d2_0     --> 0.2.1-r351h6402f54_0
#     r-lubridate:       1.7.1-r343he124285_0     --> 1.7.4-r351h32998d9_0
#     r-magrittr:        1.5-r343h889e2dd_4       --> 1.5-r351hf348343_4
#     r-maps:            3.2.0-r343h7f474d2_0     --> 3.3.0-r351h6402f54_0
#     r-markdown:        0.8-r343h7f474d2_0       --> 0.8-r351h6402f54_0
#     r-mass:            7.3_48-r343h7f474d2_0    --> 7.3_50-r351h6402f54_0
#     r-matrix:          1.2_12-r343h7f474d2_0    --> 1.2_14-r351h6402f54_0
#     r-mgcv:            1.8_22-r343h7f474d2_0    --> 1.8_24-r351h6402f54_0
#     r-mime:            0.5-r343h7f474d2_0       --> 0.5-r351h6402f54_0
#     r-miniui:          0.1.1-r343h889e2dd_0     --> 0.1.1.1-r351hf348343_0
#     r-mnormt:          1.5_5-r343h883f7c5_0     --> 1.5_5-r351h0b560c1_0
#     r-modelmetrics:    1.1.0-r343he124285_0     --> 1.1.0-r351h32998d9_0
#     r-modelr:          0.1.1-r343h889e2dd_0     --> 0.1.2-r351hf348343_0
#     r-mongolite:       1.4-r343h7f474d2_0       --> 1.6-r351h46e59ec_1
#     r-munsell:         0.4.3-r343h889e2dd_0     --> 0.5.0-r351hf348343_0
#     r-nlme:            3.1_131-r343h883f7c5_0   --> 3.1_137-r351h0b560c1_0
#     r-nnet:            7.3_12-r343h7f474d2_0    --> 7.3_12-r351h6402f54_0
#     r-numderiv:        2016.8_1-r343h889e2dd_0  --> 2016.8_1-r351hf348343_0
#     r-odbc:            1.1.2-r343h0a44026_0     --> 1.1.5-r351h0a44026_0
#     r-openssl:         0.9.9-r343h7f474d2_0     --> 1.0.2-r351h46e59ec_1
#     r-packrat:         0.4.8_1-r343h889e2dd_0   --> 0.4.9_3-r351hf348343_0
#     r-pbdzmq:          0.3_0-r343h0a44026_1     --> 0.3_3-r351h32998d9_0
#     r-pillar:          1.0.1-r343h889e2dd_0     --> 1.3.0-r351hf348343_0
#     r-pkgconfig:       2.0.1-r343h889e2dd_0     --> 2.0.1-r351hf348343_0
#     r-pki:             0.1_5.1-r343h7f474d2_0   --> 0.1_5.1-r351h46e59ec_1
#     r-plogr:           0.1_1-r343h889e2dd_0     --> 0.2.0-r351hf348343_0
#     r-plyr:            1.8.4-r343he124285_0     --> 1.8.4-r351h32998d9_0
#     r-prodlim:         1.6.1-r343he124285_0     --> 2018.04.18-r351h32998d9_0
#     r-profvis:         0.3.4-r343h7f474d2_0     --> 0.3.5-r351h6402f54_0
#     r-psych:           1.7.8-r343h889e2dd_0     --> 1.8.4-r351hf348343_0
#     r-purrr:           0.2.4-r343h7f474d2_0     --> 0.2.5-r351h6402f54_0
#     r-quantmod:        0.4_12-r343h889e2dd_0    --> 0.4_13-r351hf348343_0
#     r-r6:              2.2.2-r343h889e2dd_0     --> 2.2.2-r351hf348343_0
#     r-randomforest:    4.6_12-r343h883f7c5_4    --> 4.6_14-r351h0b560c1_0
#     r-rappdirs:        0.3.1-r343h7f474d2_0     --> 0.3.1-r351h6402f54_0
#     r-rbokeh:          0.6.3-r343_0             --> 0.6.3-r351_0
#     r-rcolorbrewer:    1.1_2-r343h889e2dd_0     --> 1.1_2-r351hf348343_0
#     r-rcpp:            0.12.14-r343he124285_0   --> 0.12.18-r351h32998d9_0
#     r-rcpproll:        0.2.2-r343he124285_0     --> 0.3.0-r351h32998d9_0
#     r-rcurl:           1.95_4.9-r343h7f474d2_0  --> 1.95_4.11-r351h6402f54_0
#     r-readr:           1.1.1-r343he124285_0     --> 1.1.1-r351h32998d9_0
#     r-readxl:          1.0.0-r343he124285_0     --> 1.1.0-r351h32998d9_0
#     r-recipes:         0.1.1-r343h889e2dd_0     --> 0.1.3-r351hf348343_0
#     r-recommended:     3.4.3-r343_0             --> 3.5.1-r351_0
#     r-rematch:         1.0.1-r343h889e2dd_0     --> 1.0.1-r351hf348343_0
#     r-repr:            0.12.0-r343h889e2dd_0    --> 0.15.0-r351hf348343_0
#     r-reprex:          0.1.1-r343h889e2dd_0     --> 0.2.0-r351hf348343_0
#     r-reshape2:        1.4.3-r343he124285_0     --> 1.4.3-r351h32998d9_0
#     r-rjava:           0.9_9-r343h7f474d2_0     --> 0.9_10-r351h6402f54_0
#     r-rjdbc:           0.2_5-r343h889e2dd_0     --> 0.2_7.1-r351hf348343_0
#     r-rjsonio:         1.3_0-r343he124285_4     --> 1.3_0-r351h32998d9_4
#     r-rlang:           0.1.6-r343h7f474d2_0     --> 0.2.1-r351h6402f54_0
#     r-rmarkdown:       1.8-r343h889e2dd_0       --> 1.10-r351hf348343_0
#     r-robustbase:      0.92_8-r343h883f7c5_0    --> 0.93_2-r351h0b560c1_0
#     r-rpart:           4.1_11-r343h7f474d2_0    --> 4.1_13-r351h6402f54_0
#     r-rprojroot:       1.3_1-r343h889e2dd_0     --> 1.3_2-r351hf348343_0
#     r-rsconnect:       0.8.5-r343h889e2dd_0     --> 0.8.8-r351hf348343_0
#     r-rstudioapi:      0.7-r343h889e2dd_0       --> 0.7-r351hf348343_0
#     r-rvest:           0.3.2-r343h889e2dd_0     --> 0.3.2-r351hf348343_0
#     r-scales:          0.5.0-r343he124285_0     --> 0.5.0-r351h32998d9_0
#     r-selectr:         0.3_1-r343h889e2dd_0     --> 0.4_1-r351hf348343_0
#     r-sfsmisc:         1.1_1-r343h889e2dd_0     --> 1.1_2-r351hf348343_0
#     r-shiny:           1.0.5-r343h889e2dd_0     --> 1.1.0-r351hf348343_0
#     r-sourcetools:     0.1.6-r343he124285_0     --> 0.1.7-r351h32998d9_0
#     r-sparklyr:        0.8.2-r343ha5884a4_0     --> 0.8.4-r351hf348343_0
#     r-spatial:         7.3_11-r343h7f474d2_4    --> 7.3_11-r351h6402f54_4
#     r-stringi:         1.1.6-r343he124285_0     --> 1.2.4-r351h32998d9_0
#     r-stringr:         1.2.0-r343h889e2dd_0     --> 1.3.1-r351hf348343_0
#     r-survival:        2.41_3-r343h7f474d2_0    --> 2.42_6-r351h6402f54_0
#     r-tibble:          1.4.1-r343h7f474d2_0     --> 1.4.2-r351h6402f54_0
#     r-tidyr:           0.7.2-r343he124285_0     --> 0.8.1-r351h32998d9_0
#     r-tidyselect:      0.2.3-r343he124285_0     --> 0.2.4-r351h32998d9_0
#     r-tidyverse:       1.2.1-r343h889e2dd_0     --> 1.2.1-r351hf348343_0
#     r-timedate:        3042.101-r343h889e2dd_0  --> 3043.102-r351hf348343_0
#     r-ttr:             0.23_2-r343h883f7c5_0    --> 0.23_3-r351h0b560c1_0
#     r-utf8:            1.1.2-r343h7f474d2_0     --> 1.1.4-r351h6402f54_0
#     r-uuid:            0.1_2-r343h7f474d2_4     --> 0.1_2-r351h6402f54_4
#     r-viridislite:     0.2.0-r343h889e2dd_0     --> 0.3.0-r351hf348343_0
#     r-whisker:         0.3_2-r343h889e2dd_4     --> 0.3_2-r351hf348343_4
#     r-withr:           2.1.1-r343h889e2dd_0     --> 2.1.2-r351hf348343_0
#     r-xml2:            1.1.1-r343he124285_0     --> 1.2.0-r351h32998d9_0
#     r-xtable:          1.8_2-r343h889e2dd_0     --> 1.8_2-r351hf348343_0
#     r-xts:             0.10_1-r343h883f7c5_0    --> 0.11_0-r351h6402f54_0
#     r-yaml:            2.1.16-r343h7f474d2_0    --> 2.2.0-r351h6402f54_0
#     r-zoo:             1.8_0-r343h7f474d2_0     --> 1.8_3-r351h6402f54_0
#     sqlite:            3.23.1-hf1716c9_0        --> 3.28.0-ha441bb4_0
#     tk:                8.6.7-h35a86e2_3         --> 8.6.8-ha441bb4_0
#     unixodbc:          2.3.6-h3efe00b_0         --> 2.3.7-h1de35cc_0
#
#
# Downloading and Extracting Packages
# libssh2-1.8.2        | 221 KB    | ##################################### | 100%
# libcurl-7.64.1       | 546 KB    | ##################################### | 100%
# r-kernlab-0.9_26     | 2.1 MB    | ##################################### | 100%
# r-rappdirs-0.3.1     | 96 KB     | ##################################### | 100%
# retrying-1.3.3       | 15 KB     | ##################################### | 100%
# r-robustbase-0.93_2  | 3.0 MB    | ##################################### | 100%
# r-packrat-0.4.9_3    | 448 KB    | ##################################### | 100%
# r-ipred-0.9_6        | 383 KB    | ##################################### | 100%
# r-formatr-1.5        | 150 KB    | ##################################### | 100%
# sqlite-3.28.0        | 2.3 MB    | ##################################### | 100%
# r-viridislite-0.3.0  | 63 KB     | ##################################### | 100%
# libedit-3.1.20181209 | 159 KB    | ##################################### | 100%
# r-forcats-0.3.0      | 211 KB    | ##################################### | 100%
# r-colorspace-1.3_2   | 512 KB    | ##################################### | 100%
# r-assertthat-0.2.0   | 57 KB     | ##################################### | 100%
# r-cli-1.0.0          | 323 KB    | ##################################### | 100%
# r-codetools-0.2_15   | 91 KB     | ##################################### | 100%
# unixodbc-2.3.7       | 271 KB    | ##################################### | 100%
# r-glue-1.3.0         | 94 KB     | ##################################### | 100%
# r-lubridate-1.7.4    | 1.0 MB    | ##################################### | 100%
# r-rcpproll-0.3.0     | 107 KB    | ##################################### | 100%
# curl-7.64.1          | 131 KB    | ##################################### | 100%
# r-rjdbc-0.2_7.1      | 101 KB    | ##################################### | 100%
# r-tidyselect-0.2.4   | 118 KB    | ##################################### | 100%
# r-sparklyr-0.8.4     | 2.7 MB    | ##################################### | 100%
# tk-8.6.8             | 3.2 MB    | ##################################### | 100%
# r-zoo-1.8_3          | 1.0 MB    | ##################################### | 100%
# r-rlang-0.2.1        | 768 KB    | ##################################### | 100%
# r-xts-0.11_0         | 896 KB    | ##################################### | 100%
# r-matrix-1.2_14      | 3.7 MB    | ##################################### | 100%
# r-highr-0.7          | 46 KB     | ##################################### | 100%
# r-bitops-1.0_6       | 27 KB     | ##################################### | 100%
# r-bit-1.1_14         | 234 KB    | ##################################### | 100%
# r-cvst-0.2_2         | 89 KB     | ##################################### | 100%
# r-repr-0.15.0        | 105 KB    | ##################################### | 100%
# r-evaluate-0.11      | 76 KB     | ##################################### | 100%
# r-r6-2.2.2           | 275 KB    | ##################################### | 100%
# r-squarem-2017.10_1  | 289 KB    | ##################################### | 100%
# r-nlme-3.1_137       | 2.2 MB    | ##################################### | 100%
# r-pls-2.6_0          | 1.2 MB    | ##################################### | 100%
# r-dbi-1.0.0          | 873 KB    | ##################################### | 100%
# r-stringr-1.3.1      | 184 KB    | ##################################### | 100%
# r-broom-0.5.0        | 1.9 MB    | ##################################### | 100%
# r-gtable-0.2.0       | 88 KB     | ##################################### | 100%
# r-mass-7.3_50        | 1.1 MB    | ##################################### | 100%
# freetype-2.9.1       | 864 KB    | ##################################### | 100%
# r-irkernel-0.8.12    | 199 KB    | ##################################### | 100%
# r-dimred-0.1.0       | 615 KB    | ##################################### | 100%
# r-class-7.3_14       | 93 KB     | ##################################### | 100%
# r-modelr-0.1.2       | 199 KB    | ##################################### | 100%
# r-catools-1.17.1.1   | 214 KB    | ##################################### | 100%
# r-caret-6.0_80       | 5.9 MB    | #########2                            |  25%
